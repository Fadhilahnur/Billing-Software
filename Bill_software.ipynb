# %%
from tkinter import*
import tkinter.messagebox

# %%
class Bill_App:
    def total(self):
        self.total_cosmetic_price=float((self.soap.get()*10)
                                   +(self.shampoo.get()*12)
                                   +(self.facemask.get()*3)
                                   +(self.gel.get()*14)
                                   +(self.spray.get()*18)
                                   +(self.lotion.get()*9))
        self.cosmetic_price.set(self.total_cosmetic_price)
        
        self.total_grocery_price=float((self.seasoning.get()*3)
                                   +(self.rice.get()*25)
                                   +(self.oil.get()*18)
                                   +(self.flour.get()*2)
                                   +(self.sugar.get()*4)
                                   +(self.tea.get()*7))
        self.grocery_price.set(self.total_grocery_price)
        
        
        self.total_beverages_price=float((self.coke.get()*3)
                                   +(self.sprite.get()*2)
                                   +(self.milo.get()*4)
                                   +(self.milk.get()*3)
                                   +(self.oranges.get()*4)
                                   +(self.strawberry.get()*3))
        self.beverages_price.set(self.total_beverages_price)
        
        self.overall.set(float(self.grocery_price.get())+float(self.cosmetic_price.get())+float(self.beverages_price.get()))
        

    def __init__(self,root):
        self.root=root
        self.root.geometry("1200x700")
        self.root.title("Billing Software")
        self.root.resizable(False, False)
        #========top title=============================================#
        bg_color="#074463"
        title=Label(self.root, 
                    text = "Billing Software", 
                    bd=12, 
                    relief=GROOVE, 
                    bg=bg_color,
                    fg='white',
                    font=("times new roman", 30, "bold"),
                    pady=2).pack(fill=X)
        
        #=====================Define Variable here=====================#
        #======================Cosmetics Variable======================#
        self.soap=IntVar()
        self.shampoo=IntVar()
        self.facemask=IntVar()
        self.gel=IntVar()
        self.spray=IntVar()
        self.lotion=IntVar()
       #======================Grocery Variable======================#
        self.seasoning=IntVar()
        self.rice=IntVar()
        self.oil=IntVar()
        self.flour=IntVar()
        self.sugar=IntVar()
        self.tea=IntVar()
        #======================Beverages Variable======================#
        self.coke=IntVar()
        self.sprite=IntVar()
        self.milo=IntVar()
        self.milk=IntVar()
        self.oranges=IntVar()
        self.strawberry=IntVar()
        #======================Bill total Variable======================#
        self.cosmetic_price=IntVar()
        self.grocery_price=IntVar()
        self.beverages_price=IntVar()
        self.overall=IntVar()
        #=================Customer Detail Variable======================#
        self.name=StringVar()
        self.phone=StringVar()
        self.bill=StringVar()
        self.searchbill=StringVar()
        
        #==========Customer Detail Frame===============================#
        Frame1=LabelFrame(self.root, 
                          text="Customer Details",
                          bd=8,
                          fg="gold",
                          bg=bg_color,
                          font=("times new roman", 14, "bold"))
        Frame1.place(x=0, y=80, relwidth=1)

        #===========Label and entry box================================#                 
        lblCustName=Label(Frame1, 
                          text="Customer Name",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=0, column=0, padx=5, pady=5)
        
        inputCustName=Entry(Frame1,
                            width=12,
                            textvariable=self.name,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=0, column=1, padx=5, pady=5)
        lblPhoneNum=Label(Frame1, 
                          text="Customer Phone No.",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=0, column=2, padx=5, pady=5)
        
        inputPhoneNume=Entry(Frame1,
                            width=12,
                            textvariable=self.phone,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=0, column=3, padx=5, pady=5)
        lblBillNumm=Label(Frame1, 
                          text="Bill Number",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=0, column=4, padx=5, pady=5)
        
        inputBillNum=Entry(Frame1,
                            width=12,
                           textvariable=self.searchbill,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=0, column=5, padx=5, pady=5)
        btnSearch=Button(Frame1,
                       text="Search",
                       width=8,
                       font="arial 12 bold").grid(row=0, column=6,padx=5, pady=5)

        #==========Cosmetic Frame====================================#
        Frame2=LabelFrame(self.root, 
                          text="Cosmetics",
                          bd=8,
                          fg="gold",
                          bg=bg_color,
                          font=("times new roman", 14, "bold"))
        Frame2.place(x=5, y=160, width=300, height=380)

        #===========Label and entry box================================#  
        lblproduct1=Label(Frame2, 
                          text="Bath Soap",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=0, column=0, padx=10, pady=10)
        
        inputproduct1=Entry(Frame2,
                            width=12,
                            textvariable=self.soap,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=0, column=1, padx=10, pady=10)
        lblproduct2=Label(Frame2, 
                          text="Shampoo",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=1, column=0, padx=10, pady=10)
        
        inputproduct2=Entry(Frame2,
                            width=12,
                            textvariable=self.shampoo,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=1, column=1, padx=10, pady=10)
        lblproduct3=Label(Frame2, 
                          text="Face Mask",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=2, column=0, padx=10, pady=10)
        
        inputproduct3=Entry(Frame2,
                            width=12,
                            textvariable=self.facemask,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=2, column=1, padx=10, pady=10)
        lblproduct4=Label(Frame2, 
                          text="Hair Gel",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=3, column=0, padx=10, pady=10)
        
        inputproduct4=Entry(Frame2,
                            width=12,
                            textvariable=self.gel,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=3, column=1, padx=10, pady=10)
        lblproduct5=Label(Frame2, 
                          text="Hair Spray",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=4, column=0, padx=10, pady=10)
        
        inputproduct5=Entry(Frame2,
                            width=12,
                            textvariable=self.spray,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=4, column=1, padx=10, pady=10)
        lblproduct6=Label(Frame2, 
                          text="Body lotion",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=5, column=0, padx=10, pady=10)
        
        inputproduct6=Entry(Frame2,
                            width=12,
                            textvariable=self.lotion,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=5, column=1, padx=10, pady=10)

        #==========Grocery Frame==========================================#
        Frame3=LabelFrame(self.root, 
                          text="Grocery",
                          bd=8,
                          fg="gold",
                          bg=bg_color,
                          font=("times new roman", 14, "bold"))
        Frame3.place(x=300, y=160, width=300, height=380)

        #===========Label and entry box================================#  
        lblproduct1=Label(Frame3, 
                          text="Seasoning",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=0, column=0, padx=10, pady=10)
        
        inputproduct1=Entry(Frame3,
                            width=12,
                            textvariable=self.seasoning,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=0, column=1, padx=10, pady=10)
        lblproduct2=Label(Frame3, 
                          text="Rice",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=1, column=0, padx=10, pady=10)
        
        inputproduct2=Entry(Frame3,
                            width=12,
                            textvariable=self.rice,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=1, column=1, padx=10, pady=10)
        lblproduct3=Label(Frame3, 
                          text="Cooking Oil",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=2, column=0, padx=10, pady=10)
        
        inputproduct3=Entry(Frame3,
                            width=12,
                            textvariable=self.oil,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=2, column=1, padx=10, pady=10)
        lblproduct4=Label(Frame3, 
                          text="Flour",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=3, column=0, padx=10, pady=10)
        
        inputproduct4=Entry(Frame3,
                            width=12,
                            textvariable=self.flour,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=3, column=1, padx=10, pady=10)
        lblproduct5=Label(Frame3, 
                          text="Sugar",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=4, column=0, padx=10, pady=10)
        
        inputproduct5=Entry(Frame3,
                            width=12,
                            textvariable=self.sugar,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=4, column=1, padx=10, pady=10)
        lblproduct6=Label(Frame3, 
                          text="Tea",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=5, column=0, padx=10, pady=10)
        
        inputproduct6=Entry(Frame3,
                            width=12,
                            textvariable=self.tea,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=5, column=1, padx=10, pady=10)
        #==========Beverages Frame==========================================#
        Frame4=LabelFrame(self.root, 
                          text="Beverages",
                          bd=8,
                          fg="gold",
                          bg=bg_color,
                          font=("times new roman", 14, "bold"))
        Frame4.place(x=600, y=160, width=300, height=380)

        #===========Label and entry box================================#  
        lblproduct1=Label(Frame4, 
                          text="Coca-cola",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=0, column=0, padx=10, pady=10)
        
        inputproduct1=Entry(Frame4,
                            width=12,
                            textvariable=self.coke,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=0, column=1, padx=10, pady=10)
        lblproduct2=Label(Frame4, 
                          text="Sprite",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=1, column=0, padx=10, pady=10)
        
        inputproduct2=Entry(Frame4,
                            width=12,
                            textvariable=self.sprite,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=1, column=1, padx=10, pady=10)
        lblproduct3=Label(Frame4, 
                          text="Milo",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=2, column=0, padx=10, pady=10)
        
        inputproduct3=Entry(Frame4,
                            width=12,
                            textvariable=self.milo,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=2, column=1, padx=10, pady=10)
        lblproduct4=Label(Frame4, 
                          text="Milk ",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=3, column=0, padx=10, pady=10)
        
        inputproduct4=Entry(Frame4,
                            width=12,
                            textvariable=self.milk,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=3, column=1, padx=10, pady=10)
        lblproduct5=Label(Frame4, 
                          text="Oranges",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=4, column=0, padx=10, pady=10)
        
        inputproduct5=Entry(Frame4,
                            width=12,
                            textvariable=self.oranges,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=4, column=1, padx=10, pady=10)
        lblproduct6=Label(Frame4, 
                          text="Strawberry",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 14, "bold")).grid(row=5, column=0, padx=10, pady=10)
        
        inputproduct6=Entry(Frame4,
                            width=12,
                            textvariable=self.strawberry,
                            font="arial 15",
                            bd=7,
                            relief=SUNKEN).grid(row=5, column=1, padx=10, pady=10)
        
        #==========Billing Frame==========================================#
        Frame5=LabelFrame(self.root, 
                          bd=8,
                         relief=GROOVE)
        Frame5.place(x=900, y=160, width=300, height=380)
        bill_title=Label(Frame5, text="Bill Area", font="arial 12 bold", bd=5, relief=GROOVE).pack(fill=X)
        scrol_y=Scrollbar(Frame5, orient=VERTICAL)
        self.txtarea=Text(Frame5, yscrollcommand=scrol_y.set)
        scrol_y.pack(side=RIGHT, fill=Y)
        scrol_x=Scrollbar(Frame5, orient=HORIZONTAL)
        self.txtarea=Text(Frame5, xscrollcommand=scrol_x.set)
        scrol_x.pack(side=BOTTOM, fill=X)
        self.txtarea.pack(fill=BOTH, expand=1)
        
        #==========Bottom Frame===============================#
        Frame6=LabelFrame(self.root, 
                          text="Billing Total",
                          bd=8,
                          fg="gold",
                          bg=bg_color,
                          font=("times new roman", 14, "bold"))
        Frame6.place(x=0, y=540, relwidth=1, height=140)
        
        lbltotal1=Label(Frame6, 
                          text="Total Cosmetic Price",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 12, "bold")).grid(row=0, column=0, padx=5, pady=5)
        
        inputtotal1=Entry(Frame6,
                          width=12,
                          textvariable=self.cosmetic_price,
                          font="arial 10",
                          bd=4,
                          relief=SUNKEN).grid(row=0, column=1, padx=5, pady=5)
        lbltotal2=Label(Frame6, 
                          text="Total Grocery Price",
                          fg="white",
                          bg=bg_color,
                          font=("times new roman", 12, "bold")).grid(row=0, column=2, padx=5, pady=5)
        
        inputtotal2=Entry(Frame6,
                          width=12,
                          textvariable=self.grocery_price,
                          font="arial 10",
                          bd=4,
                          relief=SUNKEN).grid(row=0, column=3, padx=5, pady=5)
        lbltotal3=Label(Frame6,
                        text="Total Beverages Price",
                        fg="white",
                        bg=bg_color,
                        font=("times new roman", 12, "bold")).grid(row=0, column=4, padx=5, pady=5)
                
        inputtotal3=Entry(Frame6,
                          width=12,
                          textvariable=self.beverages_price,
                          font="arial 10",
                          bd=4,
                          relief=SUNKEN).grid(row=0, column=5, padx=5, pady=5)
        lbltotal4=Label(Frame6, 
                        text="Overall Total Price",
                        fg="white",
                        bg=bg_color,
                        font=("times new roman", 12, "bold")).grid(row=0, column=6, padx=5, pady=5)
                
        inputtotal4=Entry(Frame6,
                          width=12,
                          textvariable=self.overall,
                          font="arial 10",
                          bd=4,
                          relief=SUNKEN).grid(row=0, column=7, padx=5, pady=5)
        
                
        btnTotal=Button(Frame6,
                        command=self.total,
                        text="Total",
                        width=8,
                        font="arial 12 bold").grid(row=0, column=8, padx=5, pady=5)                       
        
                        
        
if __name__=='__main__':
    root=Tk()
    app = Bill_App(root)
    root.mainloop()
